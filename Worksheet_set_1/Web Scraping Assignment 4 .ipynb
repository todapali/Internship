# %% [markdown]
# # 1. Scrape the details of most viewed videos on YouTube from Wikipedia:Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/You need to find following details:

# %%
#importing necessary libraries
import selenium
import pandas as pd
from bs4 import BeautifulSoup
import time

#Importing requests
import requests

# importing regex
import re

# Importing selenium webdriver
from selenium import webdriver

# Importing required Exceptions
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait

import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
#getting the specified the url
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)
time.sleep(3)

# %%
#Creating empty list
Rank = []
Name = []
Artist = []
Upload_date = []
Views = []

# %%
#scraping the data of rank
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[1]")[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
#Scraping data of video names
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[2]")[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')

# %%
#Scraping data of artist name
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[3]")[:30]:
        Artist.append(i.text)
except NoSuchElementException:        
    Artist.append('-')

# %%
#Scraping data of upload dates
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[5]")[:30]:
        Upload_date.append(i.text)
except NoSuchElementException:        
    Upload_date.append('-')

# %%
#Scraping data of views
try:
    for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//tbody//tr//td[4]")[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')

# %%
#DATA FRAMEING
Youtube=pd.DataFrame({})
Youtube['Rank'] = Rank
Youtube['Name'] = Name
Youtube['Artist'] = Artist
Youtube['Uploaded Date'] = Upload_date
Youtube['Views'] = Views

# %%
#Printing data frame
Youtube
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.  "Learning Colors – Colorful Eggs on a Farm"[22]
# 8    9.                                "Uptown Funk"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                             "Counting Stars"[34]
# 16  17.                                      "Sorry"[35]
# 17  18.                          "Thinking Out Loud"[36]
# 18  19.                                     "Axel F"[37]
# 19  20.                             "Girls Like You"[38]
# 20  21.                                      "Faded"[39]
# 21  22.                                 "Dark Horse"[40]
# 22  23.                                 "Let Her Go"[41]
# 23  24.                        "Baa Baa Black Sheep"[42]
# 24  25.                                   "Bailando"[43]
# 25  26.                                    "Lean On"[44]
# 26  27.                               "Shake It Off"[45]
# 27  28.                                    "Perfect"[46]
# 28  29.           "Waka Waka (This Time for Africa)"[47]
# 29  30.                                   "Mi Gente"[48]
#
#                                          Artist      Uploaded Date  Views
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  10.53
# 1                                    Luis Fonsi   January 12, 2017   7.82
# 2                                   LooLoo Kids    October 8, 2016   6.31
# 3                                    Ed Sheeran   January 30, 2017   5.69
# 4                                   Wiz Khalifa      April 6, 2015   5.48
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018   5.27
# 6                                     ChuChu TV      March 6, 2014   4.58
# 7                                   Miroshka TV  February 27, 2018   4.56
# 8                                   Mark Ronson  November 19, 2014   4.54
# 9                                    Get Movies   January 31, 2012   4.49
# 10                                          Psy      July 15, 2012   4.40
# 11                   Cocomelon – Nursery Rhymes       May 24, 2018   3.96
# 12                                    El Chombo      April 5, 2018   3.92
# 13                                     Maroon 5   January 14, 2015   3.68
# 14                                   Katy Perry  September 5, 2013   3.56
# 15                                  OneRepublic       May 31, 2013   3.56
# 16                                Justin Bieber   October 22, 2015   3.54
# 17                                   Ed Sheeran    October 7, 2014   3.44
# 18                                   Crazy Frog      June 16, 2009   3.32
# 19                                     Maroon 5       May 31, 2018   3.28
# 20                                  Alan Walker   December 3, 2015   3.27
# 21                                   Katy Perry  February 20, 2014   3.26
# 22                                    Passenger      July 25, 2012   3.21
# 23                   Cocomelon – Nursery Rhymes      June 25, 2018   3.21
# 24                             Enrique Iglesias     April 11, 2014   3.19
# 25                                  Major Lazer     March 22, 2015   3.19
# 26                                 Taylor Swift    August 18, 2014   3.16
# 27                                   Ed Sheeran   November 9, 2017   3.14
# 28                                      Shakira       June 4, 2010   3.12
# 29                                     J Balvin      June 29, 2017   3.07

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.

# %% [markdown]
# # Url = http://statisticstimes.com/ You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP
#
# D) GSDP
#
# E) Share
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
#getting the specified url
url = "http://statisticstimes.com/"
driver.get(url)
time.sleep(3)

# %%
#Clicking on economy section
economy = driver.find_element_by_xpath("//div[@class='navbar']//div[2]//button").click()

urls = driver.find_element_by_xpath("//div[@class='dropdown-content']//a[3]")
ineco_page = urls.get_attribute("href")
#Going to indian economy page
driver.get(ineco_page)  
time.sleep(5)

# %%
#Creating empty list
Rank = []
State = []
GSDP_1 = []
GSDP_2 = []
Share = []
GDP = []

# %%
#get the url of page containing GDP of indian states
sta_GDP = driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
GDP_url = sta_GDP.get_attribute("href")

driver.get(GDP_url)
time.sleep(6)


#Scraping data of rank
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[1]"):
    Rank.append(i.text)

    
#Scraping data of state name
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[2]"):
    State.append(i.text)

    
# Scraping data of GSDP at current price
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[3]"):
    GSDP_1.append(i.text)

    
#Scraping data of GSDP at current price
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[4]"):
    GSDP_2.append(i.text)

    
#Scraping data of Share
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[5]"):
    Share.append(i.text)

    
#Scraping data of GDP($ billion)
for i in driver.find_elements_by_xpath("//div[@id='table_id_wrapper']//tbody//tr//td[6]"):
    GDP.append(i.text)

# %%
#DATA FRAMEING
StatisticsTime=pd.DataFrame({})
StatisticsTime['Rank'] = Rank
StatisticsTime['State'] = State
StatisticsTime['GSDP at current price'] = GSDP_1
StatisticsTime['GSDP at current price'] = GSDP_2
StatisticsTime['Share'] = Share
StatisticsTime['GDP($ billion)'] = GDP

# %%
#Printing the data frame
StatisticsTime
# Out:
#    Rank                      State GSDP at current price   Share  \
# 0     1                Maharashtra             2,632,792  13.94%
# 1     2                 Tamil Nadu             1,630,208   8.63%
# 2     3              Uttar Pradesh             1,584,764   8.39%
# 3     4                    Gujarat             1,502,899   7.96%
# 4     5                  Karnataka             1,493,127   7.91%
# 5     6                West Bengal             1,089,898   5.77%
# 6     7                  Rajasthan               942,586   4.99%
# 7     8             Andhra Pradesh               862,957   4.57%
# 8     9                  Telangana               861,031   4.56%
# 9    10             Madhya Pradesh               809,592   4.29%
# 10   11                     Kerala               781,653   4.14%
# 11   12                      Delhi               774,870   4.10%
# 12   13                    Haryana               734,163   3.89%
# 13   14                      Bihar               530,363   2.81%
# 14   15                     Punjab               526,376   2.79%
# 15   16                     Odisha               487,805   2.58%
# 16   17                      Assam               315,881   1.67%
# 17   18               Chhattisgarh               304,063   1.61%
# 18   19                  Jharkhand               297,204   1.57%
# 19   20                Uttarakhand               245,895   1.30%
# 20   21            Jammu & Kashmir               155,956   0.83%
# 21   22           Himachal Pradesh               153,845   0.81%
# 22   23                        Goa                73,170   0.39%
# 23   24                    Tripura                49,845   0.26%
# 24   25                 Chandigarh                42,114   0.22%
# 25   26                 Puducherry                34,433   0.18%
# 26   27                  Meghalaya                33,481   0.18%
# 27   28                     Sikkim                28,723   0.15%
# 28   29                    Manipur                27,870   0.15%
# 29   30                   Nagaland                27,283   0.14%
# 30   31          Arunachal Pradesh                24,603   0.13%
# 31   32                    Mizoram                22,287   0.12%
# 32   33  Andaman & Nicobar Islands                     -       -
#
#    GDP($ billion)
# 0         399.921
# 1         247.629
# 2         240.726
# 3         228.290
# 4         226.806
# 5         165.556
# 6         143.179
# 7         131.083
# 8         130.791
# 9         122.977
# 10        118.733
# 11        117.703
# 12        111.519
# 13         80.562
# 14         79.957
# 15         74.098
# 16         47.982
# 17         46.187
# 18         45.145
# 19         37.351
# 20         23.690
# 21         23.369
# 22         11.115
# 23          7.571
# 24          6.397
# 25          5.230
# 26          5.086
# 27          4.363
# 28          4.233
# 29          4.144
# 30          3.737
# 31          3.385
# 32              -

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.

# %% [markdown]
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
#getting the specified url
url = "https://github.com/"
driver.get(url)
time.sleep(3)

# %%
#Getting explore button and clicking on it
explore = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary").click()

#Selecting trending option
trend_url = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)

# %%
#Creating empty list
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []

#Fetching urls for each repository
repository = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))

    
# Scraping Repository Title data
title = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)

    
# Scraping data from all repository page
for i in URLs:
    driver.get(i)
    time.sleep(3)
    
    
    # Scraping Repository Description data
    try:
        desc = driver.find_element_by_xpath("//p[@class='f4 my-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    # Scraping Contributors Count data
    try:
        contributor = driver.find_element_by_xpath("//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
        
        # Scraping Languages used data
    try:
        for i in driver.find_elements_by_xpath("//a[@class='topic-tag topic-tag-link']"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
        
#DATA FRAMEING
Github=pd.DataFrame({})
Github['Repository title'] = repository_title
Github['Repository description'] = Description
Github['Contributors count'] = Contributors
Github['Language used'] = Language
Github
# Out:
#                                      Repository title  \
# 0   BandaiNamcoResearchInc / Bandai-Namco-Research...
# 1                             Tencent / tmagic-editor
# 2                                   ganelson / inform
# 3                                     OpenRA / OpenRA
# 4                             PowerShell / PowerShell
# 5                            why20021008 / hand-write
# 6                      ml-tooling / best-of-ml-python
# 7                          spacedriveapp / spacedrive
# 8                                   Dreamacro / clash
# 9                       singularity-data / risingwave
# 10                         jsonhero-io / jsonhero-web
# 11                    papers-we-love / papers-we-love
# 12                   mattpocock / ts-error-translator
# 13                                      ellie / atuin
# 14                       ethereum-optimism / optimism
# 15                               streamxhub / streamx
# 16                                  CoreWCF / CoreWCF
# 17              Wechat-ggGitHub / Awesome-GitHub-Repo
# 18                                BoomingTech / Pilot
# 19                         521xueweihan / HelloGitHub
# 20                                     apache / flink
# 21                               klauspost / compress
# 22                                    kedacore / keda
# 23                                ddangelov / Top2Vec
# 24                                    google / wireit
#
#                                Repository description Contributors count  \
# 0   This repository provides motion datasets colle...                  -
# 1                                                   -                  -
# 2   The core software distribution for the Inform ...                  9
# 3   Open Source real-time strategy game engine for...                303
# 4                        PowerShell for every system!                399
# 5                                        模拟手写效果，节约时间。                  -
# 6   🏆 A ranked list of awesome machine learning Py...                 28
# 7   Spacedrive is an open source cross-platform fi...                 18
# 8                          A rule-based tunnel in Go.                 75
# 9   RisingWave: the next-generation streaming data...                 56
# 10  JSON Hero is an open-source, beautiful JSON ex...                  5
# 11  Papers from the computer science community to ...                253
# 12  Translate your TypeScript errors into plain En...                  4
# 13                            🐢 Magical shell history                 31
# 14                              The Optimism monorepo                 74
# 15  Make stream processing easier! Flink & Spark d...                 36
# 16           Main repository for the Core WCF project                 51
# 17                          收集整理 GitHub 上高质量、有趣的开源项目。                  -
# 18              Pilot – mini game engine for games104                 26
# 19  分享 GitHub 上有趣、入门级的开源项目。Share interesting, entr...                 11
# 20                                       Apache Flink              1,044
# 21                  Optimized Go Compression Packages                 29
# 22  KEDA is a Kubernetes-based Event Driven Autosc...                195
# 23  Top2Vec learns jointly embedded topic, documen...                  2
# 24  Wireit upgrades your npm scripts to make them ...                  5
#
#                                         Language used
# 0   [game, csharp, cross-platform, game-engine, do...
# 1   [game, csharp, cross-platform, game-engine, do...
# 2   [game, csharp, cross-platform, game-engine, do...
# 3   [game, csharp, cross-platform, game-engine, do...
# 4   [game, csharp, cross-platform, game-engine, do...
# 5   [game, csharp, cross-platform, game-engine, do...
# 6   [game, csharp, cross-platform, game-engine, do...
# 7   [game, csharp, cross-platform, game-engine, do...
# 8   [game, csharp, cross-platform, game-engine, do...
# 9   [game, csharp, cross-platform, game-engine, do...
# 10  [game, csharp, cross-platform, game-engine, do...
# 11  [game, csharp, cross-platform, game-engine, do...
# 12  [game, csharp, cross-platform, game-engine, do...
# 13  [game, csharp, cross-platform, game-engine, do...
# 14  [game, csharp, cross-platform, game-engine, do...
# 15  [game, csharp, cross-platform, game-engine, do...
# 16  [game, csharp, cross-platform, game-engine, do...
# 17  [game, csharp, cross-platform, game-engine, do...
# 18  [game, csharp, cross-platform, game-engine, do...
# 19  [game, csharp, cross-platform, game-engine, do...
# 20  [game, csharp, cross-platform, game-engine, do...
# 21  [game, csharp, cross-platform, game-engine, do...
# 22  [game, csharp, cross-platform, game-engine, do...
# 23  [game, csharp, cross-platform, game-engine, do...
# 24  [game, csharp, cross-platform, game-engine, do...

# %% [markdown]
# # 6: Scrape the details of top 100 songs on billboard.com. Url = https://www.billboard.com/

# %% [markdown]
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url = "https://www.billboard.com/"
driver.get(url)
time.sleep(6)
driver.maximize_window()

# %%
time.sleep(3)
Hot_song= driver.find_element_by_xpath("//li[@class='o-nav__list-item ']//a")
Hot_song.click()
time.sleep(3)

# %%
# Creating Blank List
Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# %%
#Scraping Song_name
song_name= driver.find_elements_by_xpath("//span[@class='chart-element__information']/span[1]")
for i in song_name:
    if i.text is None:
        Song_name.append('--')
    else:
        Song_name.append(i.text)

# %%
#Scraping Artist_name
artist_name= driver.find_elements_by_xpath("//span[@class='chart-element__information']/span[2]")
for i in artist_name:
    if i.text is None:
        Artist_name.append('--')
    else:
        Artist_name.append(i.text)

# %%
#Scraping Last_week_rank
last_week_rank= driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
for i in last_week_rank:
    if i.text is None:
        Last_week_rank.append('--')
    else:
        Last_week_rank.append(i.text)
        
#Scraping Peak_rank
peak_rank= driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
for i in peak_rank:
    if i.text is None:
        Peak_rank.append('--')
    else:
        Peak_rank.append(i.text)
        
#Scraping Weeks_on_board
weeks_on_board= driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
for i in weeks_on_board:
    if i.text is None:
        Weeks_on_board.append('--')
    else:
        Weeks_on_board.append(i.text)

Hot_Songs=pd.DataFrame({})
Hot_Songs['Song_name']=Song_name
Hot_Songs['Artist_name']=Artist_name
Hot_Songs['Last_week_rank']=Last_week_rank
Hot_Songs['Peak_rank']=Peak_rank
Hot_Songs['Weeks_on_board']=Weeks_on_board

Hot_Songs
# Out:
# Empty DataFrame
# Columns: [Song_name, Artist_name, Last_week_rank, Peak_rank, Weeks_on_board]
# Index: []

# %% [markdown]
# # 7: Scrape the details of Data science recruiters from naukri.com.

# %% [markdown]
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url=('https://www.naukri.com/naukri-dot-com-recruiters')
driver.get(url)
time.sleep(2)

# %%
#Fetching urls to navigate recruiter page
recruiter = driver.find_element_by_xpath("//a[@title='Search Recruiters']")
page_url = recruiter.get_attribute("href")

driver.get(page_url)
time.sleep(3)

# %%
# Fetching search button, sending keys and clicking on it
search = driver.find_element_by_xpath("//div[@class='inpWrap']//input") 
search.send_keys("Data science ")           
btn = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()     
time.sleep(3)

# %%
#Creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

#Scraping data of Names
for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)


#Scraping data of Designation
for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
    Designation.append(i.text)
time.sleep(3)

#Scraping data of company name
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)
time.sleep(3)
    
#scraping data of Skills 
for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
    time.sleep(3)

#Scraping data of locations
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]//span"):
    Location.append(i.text)
time.sleep(3)

# Creating dataframe for scraped data
Naukri=pd.DataFrame({})
Naukri['Name'] = Name[:50]
Naukri['Designation'] = Designation[:50]
Naukri['Company'] = Company[:50]
Naukri['Skills'] = Skills[:50]
Naukri['Location'] = Location[:50]
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# 18                                  Manisha Yadav
# 19                                    Riya Rajesh
# 20                           Rashmi Bhattacharjee
# 21                                  Faizan Kareem
# 22                                 Rithika dadwal
# 23                             Sandhya Khandagale
# 24                                      Shaun Rao
# 25                                  Azahar Shaikh
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                Dhruv Dev Dubey
# 31                                         Avodha
# 32                                      Jayanth N
# 33                                    Priya Khare
# 34                                     Ravi Dubey
# 35                                    Amit Sharma
# 36                                          Kanan
# 37                           Shashikant Chaudhary
# 38                                           Brad
# 39                                   Rutuja Pawar
# 40                            Madhusudhan Sridhar
# 41                                    Ankit Sinha
# 42                                 Gaurav Chouhan
# 43                                   Rashi Kacker
# 44                                        Ashwini
# 45                                   Balaji Kolli
# 46                                 Rajani Nagaraj
# 47                                    ROHIT Kumar
# 48                                 Amir Chowdhury
# 49                                       SREEDHAR
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                           HR Manager
# 11                     Executive Hiring
# 12                           Company HR
# 13                           Company HR
# 14                         HR Team Lead
# 15                 Assistant Manager HR
# 16                           HR Manager
# 17  Senior Executive Talent Acquisition
# 18                         HR Executive
# 19           Manager Talent Acquisition
# 20                              HR Head
# 21                           HR MANAGER
# 22                         HR Recruiter
# 23                         HR Recruiter
# 24              Manager Human Resources
# 25                    Company Recruiter
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30             Company Recruitment Head
# 31       Business Development Associate
# 32                      Project Manager
# 33                       Senior Manager
# 34                  Recruitment Manager
# 35                           Consultant
# 36         senior technology instructor
# 37             HR Recruiter/HR Excutive
# 38        Manager, Technical Recruiting
# 39                  Technical Recruiter
# 40                      Erp Implementer
# 41                       Head Analytics
# 42              Chief Technical Officer
# 43                   Sr Product Manager
# 44             Director Global Delivery
# 45                           Co Founder
# 46                           HR Manager
# 47                            Architect
# 48                     Managing Partner
# 49               Recruitment Consultant
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                   Infinitive Software Solutions
# 11                              Innominds Software
# 12                                        MoneyTap
# 13              QuantMagnum Technologies Pvt. Ltd.
# 14                               SocialPrachar.com
# 15                   BIZ INFOTECNO PRIVATE LIMITED
# 16                                  BISP Solutions
# 17                           Bristlecone India Ltd
# 18                                        Easi Tax
# 19                     Novelworx Digital Solutions
# 20         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 21                   FirstTech Consaltants Pvt.Ltd
# 22                                Affine Analytics
# 23                 Compumatrice Multimedia Pvt Ltd
# 24                              Exela Technologies
# 25                 NEAL ANALYTICS SERVICES PVT LTD
# 26      Autumn Leaf Consulting Services Private...
# 27                                         trainin
# 28                            Nanoprecise Sci Corp
# 29                  R.S Consultancy &amp; Services
# 30                                    Confidential
# 31                              Nikitha Palaparthi
# 32        Dollarbird Information Services Pvt, Ltd
# 33                          Independent Consultant
# 34                     HyrEzy Talent Solutions LLP
# 35                                 ASCO consulting
# 36                                         NY INST
# 37  3D India Staffing Research &amp; Consulting...
# 38                                     O.C. Tanner
# 39                                   Demand Matrix
# 40                             MADHUSUDHAN SRIDHAR
# 41                                  Suntech Global
# 42                        Strategic Consulting Lab
# 43                            Impel Labs Pvt. Ltd.
# 44                                    MRP Advisers
# 45                   Saras Solutions India Pvt Ltd
# 46                                     WildJasmine
# 47                             LNT Private Limited
# 48                                     Granular.ai
# 49     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
#
#                                                Skills  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Oracle Dba, Data Science, Data Warehousing, ET...
# 11  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 12  Business Intelligence, Data Warehousing, Data ...
# 13  Office Administration, Hr Administration, tele...
# 14  Social Media, digital media maketing, seo, smm...
# 15  React.js, Data Science, Java, Front End, Busin...
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 18  Telecalling, Client Interaction, Marketing, Re...
# 19                                       Data Science
# 20  Corporate Sales, Software Development, Softwar...
# 21  Data Analytics, Data Science, Machine Learning...
# 22  Data Science, Machine Learning, Python, R, Dee...
# 23  Big Data, Data Science, Artificial Intelligenc...
# 24  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 25  Data Science, Artificial Intelligence, Machine...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Server Administartion, Verilog, Vhdl, Digital ...
# 31  Ethical Hacking, Security Operations Center, S...
# 32  Data Analytics, Managed Services, Team Leading...
# 33  Data Science, Artificial Intelligence, analyti...
# 34  Walmart Interra Skeps Expressstores indifi whi...
# 35  Machine Learning, Artificial Intelligence, Dat...
# 36  C, C++, Artificial Intelligence, Python, Php, ...
# 37  Relationship Management, Retail Sales, Private...
# 38                 Data Science, Software Engineering
# 39  Data Science, Big Data Analytics, Digital Mark...
# 40                  Data Science, Recruitment, Salary
# 41  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 42  Software Development, Business Intelligence, B...
# 43                   Data Science, Node.js, Angularjs
# 44  Data Science, Media Marketing, Resource Planni...
# 45  Data Analysis, Learning, Data Science, Compute...
# 46  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 47  Software Development, Core Java, Unit Testing,...
# 48  Machine Learning, Data Science, Product Manage...
# 49  Data Science, Machine Learning, Big Data Analy...
#
#                                          Location
# 0                                    Aakash Harit
# 1                                      HR Manager
# 2                                           Delhi
# 3                            shravan Kumar Gaddam
# 4                               Company Recruiter
# 5                        Hyderabad / Secunderabad
# 6                        MARSIAN Technologies LLP
# 7                                      Company HR
# 8                                            Pune
# 9                                    Anik Agrawal
# 10                              Company Recruiter
# 11                                      Ahmedabad
# 12                                   subhas patel
# 13                                    Founder CEO
# 14                                  UK - (london)
# 15   Abhishek - Only Analytics Hiring - India and
# 16                    Recruitment Lead Consultant
# 17                              Vadodara / Baroda
# 18  Institute for Financial Management and Resear
# 19                              Programme Manager
# 20                                        Chennai
# 21                                    Balu Ramesh
# 22                               HR Administrator
# 23                                     Trivandrum
# 24                                  Asif Lucknowi
# 25                                       Director
# 26                                         Indore
# 27                                InstaFinancials
# 28                                 Human Resource
# 29                          Bengaluru / Bangalore
# 30                                 Priyanka Akiri
# 31                                     HR Manager
# 32                                      Hyderabad
# 33                                Kalpana Dumpala
# 34                               Executive Hiring
# 35                       Hyderabad / Secunderabad
# 36                                        Mubarak
# 37                                     Company HR
# 38                          Bengaluru / Bangalore
# 39                                 Kushal Rastogi
# 40                                     Company HR
# 41                                         Mumbai
# 42                             Mahesh Babu Channa
# 43                                   HR Team Lead
# 44                       Hyderabad / Secunderabad
# 45                                Sakshi Chhikara
# 46                           Assistant Manager HR
# 47                                     Chandigarh
# 48                                   Kapil Devang
# 49                                     HR Manager

# %% [markdown]
# # 8: Scrape the details of Highest selling novels.

# %% [markdown]
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url=('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/')
driver.get(url)

# %%
#Creating empty list
Book_name = []
Author_name = []
Volumes_sold = []
Publisher = []
Genre = []

#scraping book names data
for i in driver.find_elements_by_xpath("//tbody//tr/td[2]"):
    Book_name.append(i.text)

    
#Scraping author names data
for i in driver.find_elements_by_xpath("//tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author_name.append(i.text)
    except NoSuchElementException:
        Author_name.append('-')
time.sleep(1)


#Scraping data of volumes sold
for i in driver.find_elements_by_xpath("//tbody/tr/td[4]"):
    Volumes_sold.append(i.text)

    
#Scraping data of publisher names
for i in driver.find_elements_by_xpath("//tbody/tr/td[5]"):
    Publisher.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements_by_xpath("//tbody/tr/td[6]"):
    Genre.append(i.text)
    
#Creating dataframe for scraped data
Novels=pd.DataFrame({})
Novels['Book Name'] = Book_name
Novels['Author'] = Author_name
Novels['Volume sold'] = Volumes_sold
Novels['Publisher'] = Publisher
Novels['Genre'] = Genre
Novels
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# # 9: Scrape the details most watched tv series of all time from imdb.com.

# %% [markdown]
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url=("https://www.imdb.com/list/ls095964455/")
driver.get(url)

# %%
#Creating empty lists.
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

#Scraping data of Names
for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

#Scraping data of Year span
for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)

#Scraping data of genre
for i in driver.find_elements_by_xpath("//span[@class='genre']"):
    Genre.append(i.text)

#Scraping data of Run time
for i in driver.find_elements_by_xpath("//span[@class='runtime']"):
    Run_time.append(i.text)

#Scraping data of Ratings
for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)
    
#Scraping data of votes
for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)
    
# Creating dataframe for scraped data
TV_series=pd.DataFrame({})
TV_series['Name'] = Name
TV_series['Year Span'] = Year_span
TV_series['Genre'] = Genre
TV_series['Run Time'] = Run_time
TV_series['Ratings'] = Ratings
TV_series['Votes'] = Votes
TV_series
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,979,798
# 1    51 min     8.7    985,507
# 2    44 min     8.2    943,639
# 3    60 min     7.5    281,882
# 4    43 min     7.6    241,826
# ..      ...     ...        ...
# 95   42 min     7.4     48,515
# 96   50 min     7.8     59,148
# 97   42 min     8.1    188,689
# 98   45 min     7.1     39,988
# 99  572 min     8.6    226,163
#
# [100 rows x 6 columns]

# %% [markdown]
# # 10: Details of Datasets from UCI machine learning repositories.

# %% [markdown]
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the Show All Dataset page through code

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
# Getting the webpage of mentioned url 
url=("https://archive.ics.uci.edu/")
driver.get(url)

# %%
# Finding view all dataset button from the webpage
viewall_dataset = driver.find_element_by_xpath("//tbody[1]//tr/td[2]/span[2]/a")    
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)
time.sleep(3)

# %%
# Fetching page urls of all datasets 
view_list = driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")  
list_url = view_list.get_attribute("href")           
driver.get(list_url)
time.sleep(3)

# %%
# Fetching urls for each dataset
dataset_url = driver.find_elements_by_xpath("//p[@class='normal']//b/a")    

urls = []     
for i in dataset_url:
    urls.append(i.get_attribute("href"))

# %%
#Creating empty lists
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    
    #Scraping Dataset name
    try: 
        dataset_name = driver.find_element_by_xpath("//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    time.sleep(2)
    
    #Scraping data type
    try:
        data_type = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(2)
    
    #scraping Task
    try:
        task = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(2)
    
    # Scraping Attribute type
    try:
        attribute_type = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    time.sleep(2)
    
    # Scraping No of instances
    try:
        instances = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    time.sleep(2)
    
    # Scraping No of attributes
    try:
        attribute = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
    time.sleep(2)
    
    # Scraping year
    try:
        year = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(2)

# %%
# Creating dataframe for scraped data
ML=pd.DataFrame({})
ML['Data Name'] = Dataset_name
ML['Data Type'] = Data_type
ML['Task'] = Task
ML['Attribute type'] = Attribute_type
ML['No of instance'] = No_of_instances
ML['No of attributes'] = No_of_attributes
ML['Year'] = Year
ML
